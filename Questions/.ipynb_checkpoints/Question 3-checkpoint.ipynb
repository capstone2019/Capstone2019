# %% [markdown]
# ## What are the most common comorbidities in our claims data?
#
# What is the distribution of the number of comorbidities for people having at least one chronic condition of interest?
#
# What is the combination for a given chronic condition (include Chi-square as part of presented information)
#
# Denominator: People who have 2 or more chronic conditions

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats

# %%
data = pd.read_csv('../../data/reshaped_med.csv')

# %%
# Conditions of interest
conditions = ['kidney', 'mental_disorder', 'bp', 'cardiovascular', 'diabetes', 'obesity', 'cancer', 'musculoskeletal', 'copd', 'cholesterol']

# %%
def count_comorbidities(group):
    count_df = pd.DataFrame()
    count_df['member_id'] = group.head(1)['member_id']
    count_df['num_comorbidities'] = group['total_conditions'].max() - 1
    return count_df

# %%
# Get rows with at least 1 condition
with_condition = data.loc[data['total_conditions'] > 0]

# Group by member ID and count comorbidities; 2 conditions = 1 comorbidity, etc.
comorbidity_count = with_condition.groupby('member_id', as_index=False).apply(count_comorbidities)

# %%
comorbidity_count.describe()
# Out:
#        num_comorbidities
# count        5921.000000
# mean            0.991555
# std             1.208611
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             2.000000
# max             7.000000

# %%
ax = plt.subplot()
ax.boxplot(comorbidity_count['num_comorbidities'], vert=False)
ax.set_xlabel('Number of Comorbidities')
ax.set_title('Distribution of Comorbidities')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
def combination(condition):
    # Get all rows with at least 2 conditions
    comorbid = data.loc[data['flag_comorbidity'] == 1]
    
    # Get rows with and without given condition
    with_condition = comorbid.loc[data['binary_' + condition] == 1]
    without_condition = comorbid.loc[data['binary_' + condition] == 0]
    
    with_condition_counts = with_condition.groupby('member_id', as_index=False).apply(count_conditions)
    with_condition_counts = with_condition_counts.sum(axis=0)
    
    without_condition_counts = without_condition.groupby('member_id', as_index=False).apply(count_conditions)
    without_condition_counts = without_condition_counts.sum(axis=0)
    
    chi2 = []
    p = []
    num_both = []
    
    for c in conditions:
        both = with_condition_counts[c]
        condition_without_c = with_condition_counts[condition] - both
        without_condition_with_c = without_condition_counts[c]
        without_condition_without_c = len(without_condition) - without_condition_with_c
        
        c_arr = np.array([[both, condition_without_c], [without_condition_with_c, without_condition_without_c]])
        c_chi2, c_p, c_dof, c_ex= stats.chi2_contingency(c_arr)
        chi2.append(c_chi2)
        p.append(c_p)
        num_both.append(both)
    
    comorbidity_dict = {'conditions': conditions, 'chi2': chi2, 'p_value': p, 'num_members': num_both}
    return pd.DataFrame.from_dict(comorbidity_dict)

# %%
def count_conditions(group):
    counts = pd.DataFrame()
    
    counts['kidney'] = [1 if any(group['binary_kidney'] == 1) else 0]
    counts['mental_disorder'] = [1 if any(group['binary_mental_disorder'] == 1) else 0]
    counts['bp'] = [1 if any(group['binary_bp'] == 1) else 0]
    counts['cardiovascular'] = [1 if any(group['binary_cardiovascular'] == 1) else 0]
    counts['diabetes'] = [1 if any(group['binary_diabetes'] == 1) else 0]
    counts['obesity'] = [1 if any(group['binary_obesity'] == 1) else 0]
    counts['cancer'] = [1 if any(group['binary_cancer'] == 1) else 0]
    counts['musculoskeletal'] = [1 if any(group['binary_musculoskeletal'] == 1) else 0]
    counts['copd'] = [1 if any(group['binary_copd'] == 1) else 0]
    counts['cholesterol'] = [1 if any(group['binary_cholesterol'] == 1) else 0]

    return counts

# %%
kidney_df = combination('kidney')
kidney_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney  4109.551438  0.000000e+00          268
# 1  mental_disorder     1.363337  2.429601e-01            3
# 2               bp     0.415738  5.190714e-01          139
# 3   cardiovascular    48.963647  2.607507e-12          166
# 4         diabetes    72.544013  1.633480e-17          172
# 5          obesity    12.557918  3.945311e-04           87
# 6           cancer     6.670459  9.802393e-03           41
# 7  musculoskeletal     2.415592  1.201325e-01           22
# 8             copd    11.834158  5.815400e-04           44
# 9      cholesterol    41.148414  1.410977e-10          150

# %%
mental_disorder_df = combination('mental_disorder')
mental_disorder_df
# Out:
#         conditions         chi2   p_value  num_members
# 0           kidney     1.254034  0.262783            3
# 1  mental_disorder  4192.414073  0.000000           97
# 2               bp     0.168563  0.681392           53
# 3   cardiovascular     1.161507  0.281153           44
# 4         diabetes     0.994172  0.318725           31
# 5          obesity     0.024494  0.875633           23
# 6           cancer     3.663682  0.055611           16
# 7  musculoskeletal     0.000059  0.993862            6
# 8             copd     1.909876  0.166977           14
# 9      cholesterol     1.369784  0.241849           41

# %%
bp_df = combination('bp')
bp_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney    34.179672  5.025113e-09          139
# 1  mental_disorder     1.433246  2.312354e-01           53
# 2               bp  3585.797675  0.000000e+00         2190
# 3   cardiovascular     1.964749  1.610063e-01         1105
# 4         diabetes     8.687302  3.204346e-03         1094
# 5          obesity     0.333575  5.635617e-01          605
# 6           cancer    12.129955  4.961832e-04          238
# 7  musculoskeletal    16.642806  4.512112e-05          120
# 8             copd     3.596704  5.789424e-02          245
# 9      cholesterol    22.621272  1.972881e-06         1053

# %%
cardiovascular_df = combination('cardiovascular')
cardiovascular_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney    18.688117  1.539389e-05          166
# 1  mental_disorder     0.024577  8.754248e-01           44
# 2               bp    27.287271  1.753621e-07         1105
# 3   cardiovascular  3815.934720  0.000000e+00         1666
# 4         diabetes     7.817666  5.173797e-03          707
# 5          obesity     0.034440  8.527732e-01          440
# 6           cancer     4.807449  2.833696e-02          177
# 7  musculoskeletal     0.000876  9.763940e-01          107
# 8             copd    37.727080  8.136716e-10          252
# 9      cholesterol     2.425291  1.193910e-01          682

# %%
diabetes_df = combination('diabetes')
diabetes_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney    42.523968  6.982136e-11          172
# 1  mental_disorder     4.909686  2.670650e-02           31
# 2               bp    71.148458  3.313317e-17         1094
# 3   cardiovascular     3.917762  4.777843e-02          707
# 4         diabetes  3642.922945  0.000000e+00         1571
# 5          obesity    11.821266  5.855803e-04          466
# 6           cancer    15.421256  8.601532e-05          150
# 7  musculoskeletal     6.077514  1.369133e-02           85
# 8             copd     1.496405  2.212253e-01          170
# 9      cholesterol   119.660713  7.506095e-28          837

# %%
obesity_df = combination('obesity')
obesity_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney     6.548865  1.049511e-02           87
# 1  mental_disorder     0.003017  9.561975e-01           23
# 2               bp    19.486217  1.013282e-05          605
# 3   cardiovascular     4.066693  4.373681e-02          440
# 4         diabetes    26.117319  3.212892e-07          466
# 5          obesity  4044.440413  0.000000e+00          952
# 6           cancer     1.302405  2.537744e-01          114
# 7  musculoskeletal    14.533751  1.376709e-04           32
# 8             copd     2.208490  1.372529e-01           88
# 9      cholesterol     3.248699  7.148019e-02          398

# %%
cancer_df = combination('cancer')
cancer_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney     6.005527  1.426113e-02           41
# 1  mental_disorder     3.308266  6.893218e-02           16
# 2               bp     0.667718  4.138482e-01          238
# 3   cardiovascular     0.076728  7.817821e-01          177
# 4         diabetes     2.193008  1.386383e-01          150
# 5          obesity     3.010046  8.274993e-02          114
# 6           cancer  4106.182398  0.000000e+00          424
# 7  musculoskeletal    38.809993  4.671303e-10           54
# 8             copd     2.169378  1.407832e-01           52
# 9      cholesterol     1.033252  3.093961e-01          148

# %%
musculoskeletal_df = combination('musculoskeletal')
musculoskeletal_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney     2.258177  1.329105e-01           22
# 1  mental_disorder     0.004622  9.457983e-01            6
# 2               bp     0.951970  3.292182e-01          120
# 3   cardiovascular     1.633452  2.012262e-01          107
# 4         diabetes     0.951418  3.293586e-01           85
# 5          obesity    12.547730  3.966878e-04           32
# 6           cancer    36.778463  1.323442e-09           54
# 7  musculoskeletal  4200.453620  0.000000e+00          241
# 8             copd     1.881261  1.701909e-01           31
# 9      cholesterol     0.502750  4.782944e-01           83

# %%
copd_df = combination('cancer')
copd_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney     6.005527  1.426113e-02           41
# 1  mental_disorder     3.308266  6.893218e-02           16
# 2               bp     0.667718  4.138482e-01          238
# 3   cardiovascular     0.076728  7.817821e-01          177
# 4         diabetes     2.193008  1.386383e-01          150
# 5          obesity     3.010046  8.274993e-02          114
# 6           cancer  4106.182398  0.000000e+00          424
# 7  musculoskeletal    38.809993  4.671303e-10           54
# 8             copd     2.169378  1.407832e-01           52
# 9      cholesterol     1.033252  3.093961e-01          148

# %%
cholesterol_df = combination('cholesterol')
cholesterol_df
# Out:
#         conditions         chi2       p_value  num_members
# 0           kidney    14.143487  1.693825e-04          150
# 1  mental_disorder     0.014101  9.054759e-01           41
# 2               bp    55.280728  1.044880e-13         1053
# 3   cardiovascular     3.506983  6.111065e-02          682
# 4         diabetes    91.578881  1.072313e-21          837
# 5          obesity     0.000008  9.977819e-01          398
# 6           cancer    10.949028  9.365271e-04          148
# 7  musculoskeletal     3.538506  5.995946e-02           83
# 8             copd     0.042744  8.362077e-01          170
# 9      cholesterol  3787.831904  0.000000e+00         1514
