# %%
import numpy as np
import pandas as pd

# %%
med_data = pd.read_csv('../../data/claims_med_interns_2016-2018_20190304.csv')
med_data.columns
# Out:
# D:\Users\vhsu\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Member ID Encrypted', 'Claim ID', 'Service Line', 'Member Gender',
#        'Age', 'Zip (5-digit)', 'MSA', 'County', 'State', 'Employee Type',
#        'Relation', 'Line Of Business', 'Claim Status', 'Admit Type & Desc',
#        'Admit Source & Desc', 'Discharge Status Code', 'Primary ICD Rollup',
#        'Primary ICD Diagnosis Code', 'Primary ICD Diagnosis Desc',
#        '2nd ICD Rollup', '2nd ICD Diagnosis Code', '2nd ICD Diagnosis Desc',
#        '3rd ICD Rollup', '3rd ICD Diagnosis Code', '3rd ICD Diagnosis Desc',
#        '4th ICD Rollup', '4th ICD Diagnosis Code', '4th ICD Diagnosis Desc',
#        '5th ICD Rollup', '5th ICD Diagnosis Code', '5th ICD Diagnosis Desc',
#        '6th ICD Rollup', '6th ICD Diagnosis Code', '6th ICD Diagnosis Desc',
#        '7th ICD Rollup', '7th ICD Diagnosis Code', '7th ICD Diagnosis Desc',
#        '8th ICD Rollup', '8th ICD Diagnosis Code', '8th ICD Diagnosis Desc',
#        '9th ICD Rollup', '9th ICD Diagnosis Code', '9th ICD Diagnosis Desc',
#        '10th ICD Rollup', '10th ICD Diagnosis Code', '10th ICD Diagnosis Desc',
#        'Procedure Code', 'CPT Mod 1 Label', 'Primary ICD Procedure Code',
#        'Primary ICD Procedure Desc', '2nd ICD Procedure Code',
#        '2nd ICD Procedure Desc', '3rd ICD Procedure Code',
#        '3rd ICD Procedure Desc', '4th ICD Procedure Code',
#        '4th ICD Procedure Desc', 'Revenue Code', 'DRG Code', 'Service Units',
#        'Bill Type ID', 'Billed', 'Total Billed', 'Allowed', 'Total Allowed',
#        'Paid', 'Total Paid', 'HCG Setting', 'HCG Detail', 'Incurred Year'],
#       dtype='object')

# %%
def reshape(group):
    df = pd.DataFrame()
    df['gender'] = group.head(1)['Member Gender']
    df['age'] = group.head(1)['Age']
    df['postal_code'] = group.head(1)['Zip (5-digit)']
    df['county'] = group.head(1)['County']
    
    icd_codes = group['Primary ICD Diagnosis Code'] + group['2nd ICD Diagnosis Code'] + group['3rd ICD Diagnosis Code'] + group['4th ICD Diagnosis Code'] + group['5th ICD Diagnosis Code'] + group['6th ICD Diagnosis Code'] + group['7th ICD Diagnosis Code'] + group['8th ICD Diagnosis Code'] + group['9th ICD Diagnosis Code'] + group['9th ICD Diagnosis Code']
    
    hypertension = ['I10' in s for s in icd_codes]
    cardiovascular = ['heart' in s for s in group['Primary ICD Rollup']]
    diabetes = ['Diabetes' in s for s in group['Primary ICD Rollup']]
    obesity = ['E66' in s for s in group['Primary ICD Diagnosis Code']]
    cancer = ['Cancer' in s for s in group['Primary ICD Rollup']]
    musculoskeletal = ['musculoskeletal' in s for s in group['Primary ICD Rollup']]
    copd = ['Chronic obstructive pulmonary disease' in s for s in group['Primary ICD Rollup']]
    cholesterol = ['E78' in s for s in group['Primary ICD Diagnosis Code']]

    df['binary_hypertension'] = 1 if True in hypertension else 0
    df['binary_cardiovascular'] = 1 if True in cardiovascular else 0
    df['binary_diabetes'] = 1 if True in diabetes else 0
    df['binary_obesity'] = 1 if True in obesity else 0
    df['binary_cancer'] = 1 if True in cancer else 0
    df['binary_musculoskeletal'] = 1 if True in musculoskeletal else 0
    df['binary_copd'] = 1 if True in copd else 0
    df['binary_cholesterol'] = 1 if True in cholesterol else 0
    
    df['claims_hypertension'] = sum(hypertension)
    df['claims_cardiovascular'] = sum(cardiovascular)
    df['claims_diabetes'] = sum(diabetes)
    df['claims_obesity'] = sum(obesity)
    df['claims_cancer'] = sum(cancer)
    df['claims_musculoskeletal'] = sum(musculoskeletal)
    df['claims_copd'] = sum(copd)
    df['claims_cholesterol'] = sum(cholesterol)
    
    total_conditions = df['binary_hypertension'] + df['binary_cardiovascular'] + df['binary_diabetes'] + df['binary_obesity'] + df['binary_cancer'] + df['binary_musculoskeletal'] + df['binary_copd'] + df['binary_cholesterol']
    total_claims = df['claims_hypertension'] + df['claims_cardiovascular'] + df['claims_diabetes'] + df['claims_obesity'] + df['claims_cancer'] + df['claims_musculoskeletal'] + df['claims_copd'] + df['claims_cholesterol']

    df['total_conditions'] = total_conditions
    df['total_claims'] = total_claims
     
    df['flag_nonused'] = total_claims == 0
    df['flag_comorbidity'] = total_conditions > 1
        
    return df

# %%
reshaped_med_data = med_data.groupby(['Member ID Encrypted', 'Incurred Year']).apply(reshape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-c3049425e9b1> in <module>
# ----> 1 reshaped_med_data = med_data.groupby(['Member ID Encrypted', 'Incurred Year']).apply(reshape)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     172                 hasattr(splitter, 'fast_apply') and axis == 0):
#     173             try:
# --> 174                 values, mutated = splitter.fast_apply(f, group_keys)
#     175                 return group_keys, values, mutated
#     176             except reduction.InvalidApply:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in fast_apply(self, f, names)
#     856         sdata = self._get_sorted_data()
#     857         results, mutated = reduction.apply_frame_axis0(sdata, f, names,
# --> 858                                                        starts, ends)
#     859
#     860         return results, mutated
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# <ipython-input-59-7c1e5f53a119> in reshape(group)
#       2     df = pd.DataFrame()
#       3     df['gender'] = group.head(1)['Member Gender']
# ----> 4     df['age'] = group.head(1)['Age']
#       5     df['postal_code'] = group.head(1)['Zip (5-digit)']
#       6     df['county'] = group.head(1)['County']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in head(self, n)
#    4640         """
#    4641
# -> 4642         return self.iloc[:n]
#    4643
#    4644     def tail(self, n=5):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2208
#    2209         if isinstance(key, slice):
# -> 2210             return self._get_slice_axis(key, axis=axis)
#    2211
#    2212         if isinstance(key, list):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2178         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2179         if isinstance(slice_obj, slice):
# -> 2180             return self._slice(slice_obj, axis=axis, kind='iloc')
#    2181         else:
#    2182             return self.obj._take(slice_obj, axis=axis)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _slice(self, obj, axis, kind)
#     149         if axis is None:
#     150             axis = self.axis
# --> 151         return self.obj._slice(obj, axis=axis, kind=kind)
#     152
#     153     def _get_setitem_indexer(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis, kind)
#    3160         """
#    3161         axis = self._get_block_manager_axis(axis)
# -> 3162         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    3163         result = result.__finalize__(self)
#    3164
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in get_slice(self, slobj, axis)
#     697         new_axes[axis] = new_axes[axis][slobj]
#     698
# --> 699         bm = self.__class__(new_blocks, new_axes, do_integrity_check=False)
#     700         bm._consolidate_inplace()
#     701         return bm
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     116         self._consolidate_check()
#     117
# --> 118         self._rebuild_blknos_and_blklocs()
#     119
#     120     def make_empty(self, axes=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     196             rl = blk.mgr_locs
#     197             new_blknos[rl.indexer] = blkno
# --> 198             new_blklocs[rl.indexer] = np.arange(len(rl))
#     199
#     200         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
reshaped_med_data.head(10)
# Out:
#                                       gender  age  postal_code        county  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0        F   47        98335        PIERCE
# 71008ADZ2VBBDM14C   2016          13       F   54        98032          KING
# 7100UNBYH5SYEX19X   2016          14       F   63        98926      KITTITAS
#                     2018          21       F   65        98926      KITTITAS
# 71069K607Y1CQ9BV5   2016          22       M   70        98059          KING
#                     2017          27       M   71        98059          KING
#                     2018          88       M   72        98059          KING
# 7107GY7V3ZWGK7FKP   2016          246      F   57        98520  GRAYS HARBOR
#                     2017          310      F   58        98520  GRAYS HARBOR
# 7107NGE7PLEN7UMDY   2016          311      F   26        98030          KING
#
#                                        binary_hypertension  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0                      0
# 71008ADZ2VBBDM14C   2016          13                     0
# 7100UNBYH5SYEX19X   2016          14                     0
#                     2018          21                     0
# 71069K607Y1CQ9BV5   2016          22                     0
#                     2017          27                     0
#                     2018          88                     0
# 7107GY7V3ZWGK7FKP   2016          246                    0
#                     2017          310                    0
# 7107NGE7PLEN7UMDY   2016          311                    0
#
#                                        binary_cardiovascular  binary_diabetes  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0                        0                0
# 71008ADZ2VBBDM14C   2016          13                       0                0
# 7100UNBYH5SYEX19X   2016          14                       0                0
#                     2018          21                       0                0
# 71069K607Y1CQ9BV5   2016          22                       0                0
#                     2017          27                       0                1
#                     2018          88                       0                0
# 7107GY7V3ZWGK7FKP   2016          246                      0                0
#                     2017          310                      0                0
# 7107NGE7PLEN7UMDY   2016          311                      0                0
#
#                                        binary_obesity  binary_cancer  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0                 1              0
# 71008ADZ2VBBDM14C   2016          13                0              0
# 7100UNBYH5SYEX19X   2016          14                0              0
#                     2018          21                0              0
# 71069K607Y1CQ9BV5   2016          22                0              0
#                     2017          27                0              0
#                     2018          88                0              0
# 7107GY7V3ZWGK7FKP   2016          246               0              0
#                     2017          310               0              0
# 7107NGE7PLEN7UMDY   2016          311               0              0
#
#                                        binary_musculoskeletal  ...  \
# Member ID Encrypted Incurred Year                              ...
# 710087KT90EY0DZUV   2018          0                         0  ...
# 71008ADZ2VBBDM14C   2016          13                        0  ...
# 7100UNBYH5SYEX19X   2016          14                        0  ...
#                     2018          21                        0  ...
# 71069K607Y1CQ9BV5   2016          22                        0  ...
#                     2017          27                        0  ...
#                     2018          88                        0  ...
# 7107GY7V3ZWGK7FKP   2016          246                       0  ...
#                     2017          310                       0  ...
# 7107NGE7PLEN7UMDY   2016          311                       0  ...
#
#                                        claims_diabetes  claims_obesity  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0                  0              13
# 71008ADZ2VBBDM14C   2016          13                 0               0
# 7100UNBYH5SYEX19X   2016          14                 0               0
#                     2018          21                 0               0
# 71069K607Y1CQ9BV5   2016          22                 0               0
#                     2017          27                17               0
#                     2018          88                 0               0
# 7107GY7V3ZWGK7FKP   2016          246                0               0
#                     2017          310                0               0
# 7107NGE7PLEN7UMDY   2016          311                0               0
#
#                                        claims_cancer  claims_musculoskeletal  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0                0                       0
# 71008ADZ2VBBDM14C   2016          13               0                       0
# 7100UNBYH5SYEX19X   2016          14               0                       0
#                     2018          21               0                       0
# 71069K607Y1CQ9BV5   2016          22               0                       0
#                     2017          27               0                       0
#                     2018          88               0                       0
# 7107GY7V3ZWGK7FKP   2016          246              0                       0
#                     2017          310              0                       0
# 7107NGE7PLEN7UMDY   2016          311              0                       0
#
#                                        claims_copd  claims_cholesterol  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0              0                   0
# 71008ADZ2VBBDM14C   2016          13             0                   0
# 7100UNBYH5SYEX19X   2016          14             0                   0
#                     2018          21             0                   0
# 71069K607Y1CQ9BV5   2016          22             0                   0
#                     2017          27             0                   0
#                     2018          88             0                   0
# 7107GY7V3ZWGK7FKP   2016          246            0                   0
#                     2017          310            0                   0
# 7107NGE7PLEN7UMDY   2016          311            0                   0
#
#                                        total_conditions  total_claims  \
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0                   1            13
# 71008ADZ2VBBDM14C   2016          13                  0             0
# 7100UNBYH5SYEX19X   2016          14                  0             0
#                     2018          21                  0             0
# 71069K607Y1CQ9BV5   2016          22                  0             0
#                     2017          27                  1            17
#                     2018          88                  0             0
# 7107GY7V3ZWGK7FKP   2016          246                 0             0
#                     2017          310                 0             0
# 7107NGE7PLEN7UMDY   2016          311                 0             0
#
#                                        flag_nonused  flag_comorbidity
# Member ID Encrypted Incurred Year
# 710087KT90EY0DZUV   2018          0           False             False
# 71008ADZ2VBBDM14C   2016          13           True             False
# 7100UNBYH5SYEX19X   2016          14           True             False
#                     2018          21           True             False
# 71069K607Y1CQ9BV5   2016          22           True             False
#                     2017          27          False             False
#                     2018          88           True             False
# 7107GY7V3ZWGK7FKP   2016          246          True             False
#                     2017          310          True             False
# 7107NGE7PLEN7UMDY   2016          311          True             False
#
# [10 rows x 24 columns]
